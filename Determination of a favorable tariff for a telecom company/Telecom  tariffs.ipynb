# %% [markdown]
# ## Determination of a prospective tariff for a telecom company

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Megaline is a federal mobile operator. The company offers customers two tariff plans: "Smart" and "Ultra". To adjust the advertising budget, the commercial department wants to understand which tariff brings in more money. It is necessary to make a preliminary analysis of tariffs on a small sample of customers. It is necessary to analyze the behavior of customers and draw a conclusion - which tariff is better.

# %% [markdown]
# Initial data: The data contains information about 500 Megaline users for 2018.
#
# Tariff "Smart"
#
# Monthly fee: 550 rubles Includes 500 minutes of calls, 50 messages and 15 GB of Internet traffic. Cost of services in excess of the tariff package: 1. minute of conversation: 3 rubles ("Megaline" always rounds up the values of minutes and megabytes. If the user spoke only 1 second, a whole minute is counted in the tariff); 2. message: 3 rubles; 3. 1 GB of Internet traffic: 200 rubles.
#
# Tariff "Ultra"
#
# Monthly fee: 1950 rubles Includes 3000 minutes of conversation, 1000 messages and 30 GB of Internet traffic Cost of services in excess of the tariff package: 1 minute of conversation: 1 ruble; 2. message: 1 ruble; 3. 1 GB of Internet traffic: 150 rubles.

# %% [markdown]
# **The purpose of the study** is to test the hypotheses:
#
# 1. The average revenue of users of the Ultra and Smart tariffs differ
# 2. The average revenue of users from Moscow differs from the revenue of users from other regions.

# %% [markdown]
# **Research progress:**
#
# 1. Data review.
# 2. Data preprocessing.
# 3. Hypothesis testing. conclusion for each hypothesis.
# 4. General conclusion.

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in c:\users\vadim\anaconda3\lib\site-packages (0.5.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: jupyter-core in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (4.8.1)
# Requirement already satisfied: ipython-genutils in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.1.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (0.3.3)
# Requirement already satisfied: pyyaml in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: jupyter-latex-envs>=1.3.8 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (1.4.6)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (0.4.1)
# Requirement already satisfied: notebook>=4.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.4.5)
# Requirement already satisfied: nbconvert>=4.2 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.1.0)
# Requirement already satisfied: lxml in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (4.6.3)
# Requirement already satisfied: tornado in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.1)
# Requirement already satisfied: setuptools in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (58.0.4)
# Requirement already satisfied: ipython in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (7.29.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.3)
# Requirement already satisfied: testpath in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.10.0)
# Requirement already satisfied: bleach in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.0.0)
# Requirement already satisfied: nbformat>=4.4 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.1.3)
# Requirement already satisfied: jinja2>=2.4 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.11.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vadim\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: nest-asyncio in c:\users\vadim\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\vadim\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.10)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\vadim\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (6.1.12)
# Requirement already satisfied: pyzmq>=13 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-core->jupyter_contrib_nbextensions) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\vadim\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\vadim\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\vadim\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vadim\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.11.0)
# Requirement already satisfied: ipykernel in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.4.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (20.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\vadim\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\vadim\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\vadim\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.20)
# Requirement already satisfied: webencodings in c:\users\vadim\anaconda3\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: packaging in c:\users\vadim\anaconda3\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (21.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\vadim\anaconda3\lib\site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\vadim\anaconda3\lib\site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: backcall in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.20)
# Requirement already satisfied: decorator in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (5.1.0)
# Requirement already satisfied: colorama in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vadim\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\vadim\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vadim\anaconda3\lib\site-packages (from packaging->bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.0.4)

# %%
conda install --yes -c conda-forget jupyter_conrib_nbextensions
# Out:
# Collecting package metadata (current_repodata.json): ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# UnavailableInvalidChannel: The channel is not accessible or is invalid.
#   channel name: conda-forget
#   channel url: https://conda.anaconda.org/conda-forget
#   error code: 404
#
# You will need to adjust your conda configuration to proceed.
# Use `conda config --show channels` to view your configuration's current state,
# and use `conda config --show-sources` to view config file locations.

# %%
# !jupyter nbextension enable toc2/main
# Out:
# Enabling notebook extension toc2/main...
#       - Validating: ok

# %%
pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# Out:
# Collecting https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#   Downloading https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# Requirement already satisfied: ipython_genutils in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.3.3)
# Requirement already satisfied: jupyter_core in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (4.8.1)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.2.0)
# Requirement already satisfied: jupyter_latex_envs>=1.4.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (1.4.6)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (0.4.1)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (6.1.0)
# Requirement already satisfied: notebook>=6.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (6.4.5)
# Requirement already satisfied: tornado in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (6.1)
# Requirement already satisfied: traitlets>=4.1 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (5.1.0)
# Requirement already satisfied: lxml in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.5.3) (4.6.3)
# Requirement already satisfied: setuptools in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter-contrib-nbextensions==0.5.3) (58.0.4)
# Requirement already satisfied: ipython in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (7.29.0)
# Requirement already satisfied: pyyaml in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions==0.5.3) (6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.1.2)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.10.0)
# Requirement already satisfied: defusedxml in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.4.3)
# Requirement already satisfied: testpath in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.5.0)
# Requirement already satisfied: jinja2>=2.4 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.11.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.3)
# Requirement already satisfied: bleach in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.8.4)
# Requirement already satisfied: nbformat>=4.4 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (5.1.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\vadim\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.5.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vadim\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.1.1)
# Requirement already satisfied: async-generator in c:\users\vadim\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.10)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\vadim\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\vadim\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\vadim\anaconda3\lib\site-packages (from jupyter_core->jupyter-contrib-nbextensions==0.5.3) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\vadim\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\vadim\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\vadim\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vadim\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (21.2.0)
# Requirement already satisfied: ipykernel in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (6.4.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\vadim\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (20.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\vadim\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\vadim\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\vadim\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (2.20)
# Requirement already satisfied: webencodings in c:\users\vadim\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.5.1)
# Requirement already satisfied: packaging in c:\users\vadim\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (21.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\vadim\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\vadim\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions==0.5.3) (1.4.1)
# Requirement already satisfied: colorama in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.4.4)
# Requirement already satisfied: decorator in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (3.0.20)
# Requirement already satisfied: backcall in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\vadim\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vadim\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\vadim\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_latex_envs>=1.4.0->jupyter-contrib-nbextensions==0.5.3) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vadim\anaconda3\lib\site-packages (from packaging->bleach->nbconvert>=6.0->jupyter-contrib-nbextensions==0.5.3) (3.0.4)
# Building wheels for collected packages: jupyter-contrib-nbextensions
#   Building wheel for jupyter-contrib-nbextensions (setup.py): started
#   Building wheel for jupyter-contrib-nbextensions (setup.py): finished with status 'done'
#   Created wheel for jupyter-contrib-nbextensions: filename=jupyter_contrib_nbextensions-0.5.3-py2.py3-none-any.whl size=23430544 sha256=5592e511bf32f4844ebb09dab728b0b9d60bd463db6ebf823c483a2661cd1b30
#   Stored in directory: C:\Users\Vadim\AppData\Local\Temp\pip-ephem-wheel-cache-oy2s2wn0\wheels\13\bc\41\8f4309864399b9536d850bb7629b05e08c244c64dd210b4b84
# Successfully built jupyter-contrib-nbextensions
# Installing collected packages: jupyter-contrib-nbextensions
#   Attempting uninstall: jupyter-contrib-nbextensions
#     Found existing installation: jupyter-contrib-nbextensions 0.5.1
#     Uninstalling jupyter-contrib-nbextensions-0.5.1:
#       Successfully uninstalled jupyter-contrib-nbextensions-0.5.1
# Successfully installed jupyter-contrib-nbextensions-0.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 1. Preliminary output of data and consolidation into one dataframe.

# %%
import pandas as pd
from scipy import stats as st
import numpy as np
import datetime as dt
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
import math

# %%
df_calls = pd.read_csv(r'C:\Users\Vadim\Documents\Datasets\calls.csv')
df_internet = pd.read_csv(r'C:\Users\Vadim\Documents\Datasets\internet.csv')
df_messages = pd.read_csv(r'C:\Users\Vadim\Documents\Datasets\messages.csv')
df_tariffs = pd.read_csv(r'C:\Users\Vadim\Documents\Datasets\tariffs.csv')
df_users = pd.read_csv(r'C:\Users\Vadim\Documents\Datasets\users.csv')

# %%
tab_dict = [df_calls,df_internet, df_messages, df_tariffs, df_users]

for table in tab_dict:
    print("===============================")
    display(table.info())
    display(table.describe())
    display(table.head())
    print("Количество дубликатов:", table.duplicated().sum())
# Out:
# ===============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB
# None
#             duration        user_id
# count  202607.000000  202607.000000
# mean        6.755887    1253.940619
# std         5.843365     144.722751
# min         0.000000    1000.000000
# 25%         1.300000    1126.000000
# 50%         6.000000    1260.000000
# 75%        10.700000    1379.000000
# max        38.000000    1499.000000
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000
# Количество дубликатов: 0
# ===============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB
# None
#           Unnamed: 0        mb_used        user_id
# count  149396.000000  149396.000000  149396.000000
# mean    74697.500000     370.192426    1252.099842
# std     43127.054745     278.300951     144.050823
# min         0.000000       0.000000    1000.000000
# 25%     37348.750000     138.187500    1130.000000
# 50%     74697.500000     348.015000    1251.000000
# 75%    112046.250000     559.552500    1380.000000
# max    149395.000000    1724.830000    1499.000000
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000
# Количество дубликатов: 0
# ===============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB
# None
#              user_id
# count  123036.000000
# mean     1256.989410
# std       143.523967
# min      1000.000000
# 25%      1134.000000
# 50%      1271.000000
# 75%      1381.000000
# max      1499.000000
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000
# Количество дубликатов: 0
# ===============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes
# None
#        messages_included  mb_per_month_included  minutes_included  \
# count           2.000000               2.000000          2.000000
# mean          525.000000           23040.000000       1750.000000
# std           671.751442           10861.160159       1767.766953
# min            50.000000           15360.000000        500.000000
# 25%           287.500000           19200.000000       1125.000000
# 50%           525.000000           23040.000000       1750.000000
# 75%           762.500000           26880.000000       2375.000000
# max          1000.000000           30720.000000       3000.000000
#
#        rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute
# count         2.000000    2.000000         2.000000        2.000000
# mean       1250.000000  175.000000         2.000000        2.000000
# std         989.949494   35.355339         1.414214        1.414214
# min         550.000000  150.000000         1.000000        1.000000
# 25%         900.000000  162.500000         1.500000        1.500000
# 50%        1250.000000  175.000000         2.000000        2.000000
# 75%        1600.000000  187.500000         2.500000        2.500000
# max        1950.000000  200.000000         3.000000        3.000000
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
# Количество дубликатов: 0
# ===============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None
#            user_id        age
# count   500.000000  500.00000
# mean   1249.500000   46.58800
# std     144.481833   16.66763
# min    1000.000000   18.00000
# 25%    1124.750000   32.00000
# 50%    1249.500000   46.00000
# 75%    1374.250000   62.00000
# max    1499.000000   75.00000
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra
# Количество дубликатов: 0

# %% [markdown]
# **Conclusions**
#
# Tables contain such data types as int64, float and object. There are no duplicates in the tables. Gaps occur only in the last table `df_users`.

# %% [markdown]
# ### Step 2. Data preprocessing

# %% [markdown]
# #### Checking data for errors

# %%
df_users_calls = df_calls.set_index('user_id').join(df_users.set_index('user_id'))

# %%
df_users_calls.head(5)
# Out:
#              id   call_date  duration  age churn_date       city first_name  \
# user_id
# 1000     1000_0  2018-07-25      0.00   52        NaN  Краснодар     Рафаил
# 1000     1000_1  2018-08-17      0.00   52        NaN  Краснодар     Рафаил
# 1000     1000_2  2018-06-11      2.85   52        NaN  Краснодар     Рафаил
# 1000     1000_3  2018-09-21     13.80   52        NaN  Краснодар     Рафаил
# 1000     1000_4  2018-12-15      5.18   52        NaN  Краснодар     Рафаил
#
#          last_name    reg_date tariff
# user_id
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra

# %%
df_users_internet = df_internet.set_index('user_id').join(df_users.set_index('user_id'))

# %%
df_users_internet.head(5)
# Out:
#          Unnamed: 0      id  mb_used session_date  age churn_date       city  \
# user_id
# 1000              0  1000_0   112.95   2018-11-25   52        NaN  Краснодар
# 1000              1  1000_1  1052.81   2018-09-07   52        NaN  Краснодар
# 1000              2  1000_2  1197.26   2018-06-25   52        NaN  Краснодар
# 1000              3  1000_3   550.27   2018-08-22   52        NaN  Краснодар
# 1000              4  1000_4   302.56   2018-09-24   52        NaN  Краснодар
#
#         first_name  last_name    reg_date tariff
# user_id
# 1000        Рафаил  Верещагин  2018-05-25  ultra
# 1000        Рафаил  Верещагин  2018-05-25  ultra
# 1000        Рафаил  Верещагин  2018-05-25  ultra
# 1000        Рафаил  Верещагин  2018-05-25  ultra
# 1000        Рафаил  Верещагин  2018-05-25  ultra

# %% [markdown]
# View the unique values of the `Unnamed: 0` column:

# %%
df_users_internet['Unnamed: 0'].unique()
# Out:
# array([     0,      1,      2, ..., 149393, 149394, 149395], dtype=int64)

# %% [markdown]
# The `Unnamed: 0` column appears to be the row numbering in the `df_internet` dataframe

# %%
df_users_messages = df_messages.set_index('user_id').join(df_users.set_index('user_id'))

# %%
df_users_messages.head(5)
# Out:
#              id message_date  age churn_date       city first_name  last_name  \
# user_id
# 1000     1000_0   2018-06-27   52        NaN  Краснодар     Рафаил  Верещагин
# 1000     1000_1   2018-10-08   52        NaN  Краснодар     Рафаил  Верещагин
# 1000     1000_2   2018-08-04   52        NaN  Краснодар     Рафаил  Верещагин
# 1000     1000_3   2018-06-16   52        NaN  Краснодар     Рафаил  Верещагин
# 1000     1000_4   2018-12-05   52        NaN  Краснодар     Рафаил  Верещагин
#
#            reg_date tariff
# user_id
# 1000     2018-05-25  ultra
# 1000     2018-05-25  ultra
# 1000     2018-05-25  ultra
# 1000     2018-05-25  ultra
# 1000     2018-05-25  ultra

# %% [markdown]
# #### Checking data for gaps:

# %%
def isna_style(x):
    mis_val = x.isnull().sum()
    mis_val_percent = (100 * x.isnull().sum() / len(x)).round(1)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(columns = {0 : 'count_nan', 1 : '%_nan'})
    return mis_val_table_ren_columns.style.background_gradient('cool')

# %%
table_list = [df_users_calls, df_users_internet, df_users_messages]

# %%
for table in table_list:
    print("..........................")
    display(isna_style(table))
# Out:
# ..........................
# <style type="text/css">
# #T_461a9_row0_col0, #T_461a9_row0_col1, #T_461a9_row1_col0, #T_461a9_row1_col1, #T_461a9_row2_col0, #T_461a9_row2_col1, #T_461a9_row3_col0, #T_461a9_row3_col1, #T_461a9_row5_col0, #T_461a9_row5_col1, #T_461a9_row6_col0, #T_461a9_row6_col1, #T_461a9_row7_col0, #T_461a9_row7_col1, #T_461a9_row8_col0, #T_461a9_row8_col1, #T_461a9_row9_col0, #T_461a9_row9_col1 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_461a9_row4_col0, #T_461a9_row4_col1 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_461a9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count_nan</th>
#       <th class="col_heading level0 col1" >%_nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_461a9_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_461a9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_461a9_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row1" class="row_heading level0 row1" >call_date</th>
#       <td id="T_461a9_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_461a9_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row2" class="row_heading level0 row2" >duration</th>
#       <td id="T_461a9_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_461a9_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row3" class="row_heading level0 row3" >age</th>
#       <td id="T_461a9_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_461a9_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row4" class="row_heading level0 row4" >churn_date</th>
#       <td id="T_461a9_row4_col0" class="data row4 col0" >192688</td>
#       <td id="T_461a9_row4_col1" class="data row4 col1" >95.100000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row5" class="row_heading level0 row5" >city</th>
#       <td id="T_461a9_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_461a9_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row6" class="row_heading level0 row6" >first_name</th>
#       <td id="T_461a9_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_461a9_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row7" class="row_heading level0 row7" >last_name</th>
#       <td id="T_461a9_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_461a9_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row8" class="row_heading level0 row8" >reg_date</th>
#       <td id="T_461a9_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_461a9_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_461a9_level0_row9" class="row_heading level0 row9" >tariff</th>
#       <td id="T_461a9_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_461a9_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# ..........................
# <style type="text/css">
# #T_df1b9_row0_col0, #T_df1b9_row0_col1, #T_df1b9_row1_col0, #T_df1b9_row1_col1, #T_df1b9_row2_col0, #T_df1b9_row2_col1, #T_df1b9_row3_col0, #T_df1b9_row3_col1, #T_df1b9_row4_col0, #T_df1b9_row4_col1, #T_df1b9_row6_col0, #T_df1b9_row6_col1, #T_df1b9_row7_col0, #T_df1b9_row7_col1, #T_df1b9_row8_col0, #T_df1b9_row8_col1, #T_df1b9_row9_col0, #T_df1b9_row9_col1, #T_df1b9_row10_col0, #T_df1b9_row10_col1 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_df1b9_row5_col0, #T_df1b9_row5_col1 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_df1b9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count_nan</th>
#       <th class="col_heading level0 col1" >%_nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df1b9_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_df1b9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_df1b9_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row1" class="row_heading level0 row1" >id</th>
#       <td id="T_df1b9_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_df1b9_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row2" class="row_heading level0 row2" >mb_used</th>
#       <td id="T_df1b9_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_df1b9_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row3" class="row_heading level0 row3" >session_date</th>
#       <td id="T_df1b9_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_df1b9_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row4" class="row_heading level0 row4" >age</th>
#       <td id="T_df1b9_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_df1b9_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row5" class="row_heading level0 row5" >churn_date</th>
#       <td id="T_df1b9_row5_col0" class="data row5 col0" >141648</td>
#       <td id="T_df1b9_row5_col1" class="data row5 col1" >94.800000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row6" class="row_heading level0 row6" >city</th>
#       <td id="T_df1b9_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_df1b9_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row7" class="row_heading level0 row7" >first_name</th>
#       <td id="T_df1b9_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_df1b9_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row8" class="row_heading level0 row8" >last_name</th>
#       <td id="T_df1b9_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_df1b9_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row9" class="row_heading level0 row9" >reg_date</th>
#       <td id="T_df1b9_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_df1b9_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_df1b9_level0_row10" class="row_heading level0 row10" >tariff</th>
#       <td id="T_df1b9_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_df1b9_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# ..........................
# <style type="text/css">
# #T_c37e0_row0_col0, #T_c37e0_row0_col1, #T_c37e0_row1_col0, #T_c37e0_row1_col1, #T_c37e0_row2_col0, #T_c37e0_row2_col1, #T_c37e0_row4_col0, #T_c37e0_row4_col1, #T_c37e0_row5_col0, #T_c37e0_row5_col1, #T_c37e0_row6_col0, #T_c37e0_row6_col1, #T_c37e0_row7_col0, #T_c37e0_row7_col1, #T_c37e0_row8_col0, #T_c37e0_row8_col1 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_c37e0_row3_col0, #T_c37e0_row3_col1 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c37e0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count_nan</th>
#       <th class="col_heading level0 col1" >%_nan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c37e0_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_c37e0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c37e0_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row1" class="row_heading level0 row1" >message_date</th>
#       <td id="T_c37e0_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c37e0_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_c37e0_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_c37e0_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row3" class="row_heading level0 row3" >churn_date</th>
#       <td id="T_c37e0_row3_col0" class="data row3 col0" >117697</td>
#       <td id="T_c37e0_row3_col1" class="data row3 col1" >95.700000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row4" class="row_heading level0 row4" >city</th>
#       <td id="T_c37e0_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_c37e0_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row5" class="row_heading level0 row5" >first_name</th>
#       <td id="T_c37e0_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_c37e0_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row6" class="row_heading level0 row6" >last_name</th>
#       <td id="T_c37e0_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_c37e0_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row7" class="row_heading level0 row7" >reg_date</th>
#       <td id="T_c37e0_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_c37e0_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c37e0_level0_row8" class="row_heading level0 row8" >tariff</th>
#       <td id="T_c37e0_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_c37e0_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# `churn_date` - date when the tariff was discontinued (according to the initial data: if the value is omitted, then the tariff was still valid at the time of data upload). There are no gaps in the other columns.

# %% [markdown]
# #### Replacing the data type

# %% [markdown]
# Now you need to convert the data in the columns with the date to the `date` format

# %%
df_users_calls[['call_date', 'churn_date']] = df_users_calls[['call_date', 'churn_date']].apply(pd.to_datetime)

# %%
df_users_internet[['session_date', 'reg_date']] = df_users_internet[['session_date', 'reg_date']].apply(pd.to_datetime)

# %%
df_users_messages[['message_date', 'reg_date']] = df_users_messages[['message_date', 'reg_date']].apply(pd.to_datetime)

# %% [markdown]
# The tariff plan says: Megaline always rounds seconds to minutes, and megabytes to gigabytes. Each call is rounded up separately: even if it lasted only 1 second, it will be counted as 1 minute. However, for web traffic, individual sessions are not counted. Instead, the monthly total is rounded up. Therefore, we will round off web traffic when calculating the monthly amount a little later.

# %% [markdown]
# Rounding call duration:

# %%
df_users_calls['duration'] = df_users_calls['duration'].apply(lambda x: math.ceil(x))

# %%
df_users_calls
# Out:
#                id  call_date  duration  age churn_date       city first_name  \
# user_id
# 1000       1000_0 2018-07-25         0   52        NaT  Краснодар     Рафаил
# 1000       1000_1 2018-08-17         0   52        NaT  Краснодар     Рафаил
# 1000       1000_2 2018-06-11         3   52        NaT  Краснодар     Рафаил
# 1000       1000_3 2018-09-21        14   52        NaT  Краснодар     Рафаил
# 1000       1000_4 2018-12-15         6   52        NaT  Краснодар     Рафаил
# ...           ...        ...       ...  ...        ...        ...        ...
# 1499     1499_215 2018-12-26         1   35        NaT      Пермь     Гектор
# 1499     1499_216 2018-10-18        19   35        NaT      Пермь     Гектор
# 1499     1499_217 2018-11-10        11   35        NaT      Пермь     Гектор
# 1499     1499_218 2018-10-06         5   35        NaT      Пермь     Гектор
# 1499     1499_219 2018-12-14        20   35        NaT      Пермь     Гектор
#
#          last_name    reg_date tariff
# user_id
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra
# 1000     Верещагин  2018-05-25  ultra
# ...            ...         ...    ...
# 1499      Корнилов  2018-09-27  smart
# 1499      Корнилов  2018-09-27  smart
# 1499      Корнилов  2018-09-27  smart
# 1499      Корнилов  2018-09-27  smart
# 1499      Корнилов  2018-09-27  smart
#
# [202607 rows x 10 columns]

# %% [markdown]
# In the `df_tariffs` table, let's convert MB to GB:

# %%
df_tariffs['gb_per_month_included'] = df_tariffs['mb_per_month_included'] / 1024

# %% [markdown]
# #### Number of calls and spent minutes by month

# %%
df_users_calls['month'] = df_users_calls['call_date'].dt.month

# %%
df_users_calls
# Out:
#                id  call_date  duration  age churn_date       city first_name  \
# user_id
# 1000       1000_0 2018-07-25         0   52        NaT  Краснодар     Рафаил
# 1000       1000_1 2018-08-17         0   52        NaT  Краснодар     Рафаил
# 1000       1000_2 2018-06-11         3   52        NaT  Краснодар     Рафаил
# 1000       1000_3 2018-09-21        14   52        NaT  Краснодар     Рафаил
# 1000       1000_4 2018-12-15         6   52        NaT  Краснодар     Рафаил
# ...           ...        ...       ...  ...        ...        ...        ...
# 1499     1499_215 2018-12-26         1   35        NaT      Пермь     Гектор
# 1499     1499_216 2018-10-18        19   35        NaT      Пермь     Гектор
# 1499     1499_217 2018-11-10        11   35        NaT      Пермь     Гектор
# 1499     1499_218 2018-10-06         5   35        NaT      Пермь     Гектор
# 1499     1499_219 2018-12-14        20   35        NaT      Пермь     Гектор
#
#          last_name    reg_date tariff  month
# user_id
# 1000     Верещагин  2018-05-25  ultra      7
# 1000     Верещагин  2018-05-25  ultra      8
# 1000     Верещагин  2018-05-25  ultra      6
# 1000     Верещагин  2018-05-25  ultra      9
# 1000     Верещагин  2018-05-25  ultra     12
# ...            ...         ...    ...    ...
# 1499      Корнилов  2018-09-27  smart     12
# 1499      Корнилов  2018-09-27  smart     10
# 1499      Корнилов  2018-09-27  smart     11
# 1499      Корнилов  2018-09-27  smart     10
# 1499      Корнилов  2018-09-27  smart     12
#
# [202607 rows x 11 columns]

# %%
df_users_calls_agg = df_users_calls.pivot_table(index=['user_id', 'month', 'tariff'], values='duration', aggfunc=('count','sum')).rename(columns={'count': 'count_calls','sum': 'dur_calls'})

# %%
df_users_calls_agg
# Out:
#                       count_calls  dur_calls
# user_id month tariff
# 1000    5     ultra            22        159
#         6     ultra            43        172
#         7     ultra            47        340
#         8     ultra            52        408
#         9     ultra            58        466
# ...                           ...        ...
# 1498    10    smart            41        247
# 1499    9     smart             9         70
#         10    smart            68        449
#         11    smart            74        612
#         12    smart            69        492
#
# [3174 rows x 2 columns]

# %%
df_users_calls.loc[df_users_calls['duration'] == 0, 'duration'].value_counts()[0] 
# Calls with zero duration
# Out:
# 39613

# %% [markdown]
# **Plot the dependence of the number of zero values on the total number of calls for each month:**

# %%
df_users_calls.loc[df_users_calls['duration'] == 0, 'nulls_count'] = 1

null_calls_ultra = df_users_calls.loc[df_users_calls['tariff']=='ultra'].pivot_table(index='month', values=['id', 'nulls_count'], aggfunc='count')
null_calls_smart = df_users_calls.loc[df_users_calls['tariff']=='smart'].pivot_table(index='month', values=['id', 'nulls_count'], aggfunc='count')

plt.scatter(x='id', y='nulls_count', data=null_calls_ultra, color='tab:red')
plt.scatter(x='id', y='nulls_count', data=null_calls_smart, color='tab:blue')

plt.legend(loc='lower right')
plt.legend(['ultra', 'smart'])
plt.title('Dependence of the number of zero values \n on the total number of calls for each month', fontsize=14);
plt.xlabel('Total number of calls per month', fontsize=12)
plt.ylabel('Number of calls with zero \n duration', fontsize=12);

# %% [markdown]
# The graph shows that the ratio of calls with zero duration to the total number of calls per month is constant. The dependence for both tariffs is the same

# %% [markdown]
# Calls with zero duration are missed or dropped calls.

# %% [markdown]
# #### Number of messages sent by month

# %%
df_users_messages['month'] = df_users_messages['message_date'].dt.month

# %%
df_users_messages_agg = df_users_messages.pivot_table(index=['user_id','month','tariff'], values='id', aggfunc='count').rename(columns={'id': 'count_messages'})

# %%
df_users_messages_agg.head(10)
# Out:
#                       count_messages
# user_id month tariff
# 1000    5     ultra               22
#         6     ultra               60
#         7     ultra               75
#         8     ultra               81
#         9     ultra               57
#         10    ultra               73
#         11    ultra               58
#         12    ultra               70
# 1002    6     smart                4
#         7     smart               11

# %% [markdown]
# #### The amount of Internet traffic used by months

# %%
df_users_internet['month'] = df_users_internet['session_date'].dt.month

# %%
df_users_internet_agg = df_users_internet.pivot_table(index=['user_id','month', 'tariff'], values='mb_used', aggfunc='sum')

# %%
df_users_internet_agg
# Out:
#                        mb_used
# user_id month tariff
# 1000    5     ultra    2253.49
#         6     ultra   23233.77
#         7     ultra   14003.64
#         8     ultra   14055.93
#         9     ultra   14568.91
# ...                        ...
# 1498    10    smart   20579.36
# 1499    9     smart    1845.75
#         10    smart   17788.51
#         11    smart   17963.31
#         12    smart   13055.58
#
# [3203 rows x 1 columns]

# %% [markdown]
# **Plot of the number of zero indicators depending on the number of Internet sessions for each month:**

# %%
df_users_internet.loc[df_users_internet['mb_used'] == 0, 'nulls_count'] = 1
null_mb = df_users_internet.pivot_table(index='month', values=['id', 'nulls_count'], aggfunc='count')

null_internet_ultra = df_users_internet.loc[df_users_internet['tariff']=='ultra'].pivot_table(index='month', values=['id', 'nulls_count'], aggfunc='count')
null_internet_smart = df_users_internet.loc[df_users_internet['tariff']=='smart'].pivot_table(index='month', values=['id', 'nulls_count'], aggfunc='count')

plt.scatter(x='id', y='nulls_count', data=null_internet_ultra, color='tab:red')
plt.scatter(x='id', y='nulls_count', data=null_internet_smart, color='tab:blue')

plt.legend(loc='lower right')
plt.legend(['ultra', 'smart'])
plt.xlabel('Total number of internet sessions per month')
plt.ylabel('Number of internet sessions \n with zero traffic')
_ = plt.title('Dependence of the number of zero values \n on the total number of Internet sessions for each month')

# %% [markdown]
# Here, as well as with the duration of calls, there is a linear dependence of zero Internet sessions on their total number. However, the dependencies are different. At the Ultra tariff, the share of zero Internet sessions is much less. It can be assumed that a null session is a network login using anonymous authentication.

# %% [markdown]
# **Get rid of zero values in the sample so as not to distort the calculation of statistics in the future:**

# %%
df_users_calls = df_users_calls.loc[df_users_calls['duration'] != 0]
df_users_internet = df_users_internet.loc[df_users_internet['mb_used'] != 0]

# %%
df_users_internet
# Out:
#          Unnamed: 0        id  mb_used session_date  age churn_date  \
# user_id
# 1000              0    1000_0   112.95   2018-11-25   52        NaN
# 1000              1    1000_1  1052.81   2018-09-07   52        NaN
# 1000              2    1000_2  1197.26   2018-06-25   52        NaN
# 1000              3    1000_3   550.27   2018-08-22   52        NaN
# 1000              4    1000_4   302.56   2018-09-24   52        NaN
# ...             ...       ...      ...          ...  ...        ...
# 1499         149390  1499_151   752.72   2018-10-11   35        NaN
# 1499         149391  1499_152   318.90   2018-10-03   35        NaN
# 1499         149392  1499_153   490.13   2018-12-14   35        NaN
# 1499         149394  1499_155  1246.32   2018-11-26   35        NaN
# 1499         149395  1499_156   544.37   2018-10-26   35        NaN
#
#               city first_name  last_name   reg_date tariff  month  nulls_count
# user_id
# 1000     Краснодар     Рафаил  Верещагин 2018-05-25  ultra     11          NaN
# 1000     Краснодар     Рафаил  Верещагин 2018-05-25  ultra      9          NaN
# 1000     Краснодар     Рафаил  Верещагин 2018-05-25  ultra      6          NaN
# 1000     Краснодар     Рафаил  Верещагин 2018-05-25  ultra      8          NaN
# 1000     Краснодар     Рафаил  Верещагин 2018-05-25  ultra      9          NaN
# ...            ...        ...        ...        ...    ...    ...          ...
# 1499         Пермь     Гектор   Корнилов 2018-09-27  smart     10          NaN
# 1499         Пермь     Гектор   Корнилов 2018-09-27  smart     10          NaN
# 1499         Пермь     Гектор   Корнилов 2018-09-27  smart     12          NaN
# 1499         Пермь     Гектор   Корнилов 2018-09-27  smart     11          NaN
# 1499         Пермь     Гектор   Корнилов 2018-09-27  smart     10          NaN
#
# [129798 rows x 13 columns]

# %%
df_users_internet_agg.columns = [''.join(col).strip() for col in df_users_internet_agg.columns.values]

# %% [markdown]
# Rounding up web traffic for each month and converting from mb to GB:

# %%
def math_ceil(x):
    try:
        return math.ceil(x / 1024)
    except:
        return np.nan

# %%
df_users_internet_agg['gb_used'] = df_users_internet_agg['mb_used'].apply(
    lambda x: math_ceil(x))

# %%
df_users_internet_agg
# Out:
#                        mb_used  gb_used
# user_id month tariff
# 1000    5     ultra    2253.49        3
#         6     ultra   23233.77       23
#         7     ultra   14003.64       14
#         8     ultra   14055.93       14
#         9     ultra   14568.91       15
# ...                        ...      ...
# 1498    10    smart   20579.36       21
# 1499    9     smart    1845.75        2
#         10    smart   17788.51       18
#         11    smart   17963.31       18
#         12    smart   13055.58       13
#
# [3203 rows x 2 columns]

# %% [markdown]
# #### Calculation of monthly revenue for each tariff

# %% [markdown]
# Tariff "Smart"
# - Monthly fee: 550 rubles
# - Included 500 minutes of calls, 50 messages and 15 GB of internet traffic
# - The cost of services in excess of the tariff package: 1. minute of conversation: 3 rubles ("Megaline" always rounds up the values of minutes and megabytes. If the user spoke only 1 second, a whole minute is counted in the tariff); 2. message: 3 rubles; 3. 1 GB of Internet traffic: 200 rubles.
#
# Tariff "Ultra"
# - Monthly fee: 1950 rubles
# - Included 3000 minutes of calls, 1000 messages and 30 GB of internet traffic
# - Cost of services in excess of the tariff package: 1. minute of conversation: 1 ruble; 2. message: 1 ruble; 3. 1 GB of Internet traffic: 150 rubles.

# %%
df_general_agg = df_users_calls_agg.join([df_users_messages_agg, df_users_internet_agg], how='outer').reset_index()

# %%
df_general_agg.head(10)
# Out:
#    user_id  month tariff  count_calls  dur_calls  count_messages   mb_used  \
# 0     1000      5  ultra         22.0      159.0            22.0   2253.49
# 1     1000      6  ultra         43.0      172.0            60.0  23233.77
# 2     1000      7  ultra         47.0      340.0            75.0  14003.64
# 3     1000      8  ultra         52.0      408.0            81.0  14055.93
# 4     1000      9  ultra         58.0      466.0            57.0  14568.91
# 5     1000     10  ultra         57.0      350.0            73.0  14702.49
# 6     1000     11  ultra         43.0      338.0            58.0  14756.47
# 7     1000     12  ultra         46.0      333.0            70.0   9817.61
# 8     1001     11  smart         59.0      430.0             NaN  18429.34
# 9     1001     12  smart         63.0      414.0             NaN  14036.66
#
#    gb_used
# 0      3.0
# 1     23.0
# 2     14.0
# 3     14.0
# 4     15.0
# 5     15.0
# 6     15.0
# 7     10.0
# 8     18.0
# 9     14.0

# %%
df_general_agg = df_general_agg.merge(df_tariffs, left_on='tariff', right_on='tariff_name')

# %%
df_general_agg = df_general_agg.set_index('user_id').join(df_users[['city', 'user_id']].set_index('user_id'))

# %%
df_general_agg.head(10)
# Out:
#          month tariff  count_calls  dur_calls  count_messages   mb_used  \
# user_id
# 1000         5  ultra         22.0      159.0            22.0   2253.49
# 1000         6  ultra         43.0      172.0            60.0  23233.77
# 1000         7  ultra         47.0      340.0            75.0  14003.64
# 1000         8  ultra         52.0      408.0            81.0  14055.93
# 1000         9  ultra         58.0      466.0            57.0  14568.91
# 1000        10  ultra         57.0      350.0            73.0  14702.49
# 1000        11  ultra         43.0      338.0            58.0  14756.47
# 1000        12  ultra         46.0      333.0            70.0   9817.61
# 1001        11  smart         59.0      430.0             NaN  18429.34
# 1001        12  smart         63.0      414.0             NaN  14036.66
#
#          gb_used  messages_included  mb_per_month_included  minutes_included  \
# user_id
# 1000         3.0               1000                  30720              3000
# 1000        23.0               1000                  30720              3000
# 1000        14.0               1000                  30720              3000
# 1000        14.0               1000                  30720              3000
# 1000        15.0               1000                  30720              3000
# 1000        15.0               1000                  30720              3000
# 1000        15.0               1000                  30720              3000
# 1000        10.0               1000                  30720              3000
# 1001        18.0                 50                  15360               500
# 1001        14.0                 50                  15360               500
#
#          rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# user_id
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1001                 550         200                3               3
# 1001                 550         200                3               3
#
#         tariff_name  gb_per_month_included       city
# user_id
# 1000          ultra                   30.0  Краснодар
# 1000          ultra                   30.0  Краснодар
# 1000          ultra                   30.0  Краснодар
# 1000          ultra                   30.0  Краснодар
# 1000          ultra                   30.0  Краснодар
# 1000          ultra                   30.0  Краснодар
# 1000          ultra                   30.0  Краснодар
# 1000          ultra                   30.0  Краснодар
# 1001          smart                   15.0     Москва
# 1001          smart                   15.0     Москва

# %%
df_general_agg.isna().sum()
# Out:
# month                      0
# tariff                     0
# count_calls               40
# dur_calls                 40
# count_messages           497
# mb_used                   11
# gb_used                   11
# messages_included          0
# mb_per_month_included      0
# minutes_included           0
# rub_monthly_fee            0
# rub_per_gb                 0
# rub_per_message            0
# rub_per_minute             0
# tariff_name                0
# gb_per_month_included      0
# city                       0
# dtype: int64

# %%
df_general_agg = df_general_agg.fillna(0)

# %%
# %%timeit
def proceeds_calls(dur_calls, minutes_included, rub_monthly_fee, rub_per_minute):
    if dur_calls <= minutes_included:
        return rub_monthly_fee
    else:
        return rub_monthly_fee + (dur_calls - minutes_included) * rub_per_minute

def proceeds_message(count_messages, messages_included, rub_per_message):
    if count_messages <= messages_included:
        return 0
    else:
        return (count_messages - messages_included) * rub_per_message    

def proceeds_traffic(gb_used, gb_per_month_included, rub_per_gb):
    if gb_used <= gb_per_month_included:
        return 0
    else:
        return (gb_used - gb_per_month_included) * rub_per_gb

df_general_agg['revenue'] = df_general_agg.apply(
    lambda row: proceeds_calls(
        row['dur_calls'], 
        row['minutes_included'], 
        row['rub_monthly_fee'], 
        row['rub_per_minute']), axis=1) + df_general_agg.apply(
    lambda row: proceeds_message(
        row['count_messages'], 
        row['messages_included'], 
        row['rub_per_message']), axis=1) + df_general_agg.apply(
    lambda row: proceeds_traffic(
        row['gb_used'], 
        row['gb_per_month_included'], 
        row['rub_per_gb']), axis=1)
# Out:
# 90.3 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df_tariffs
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name  \
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
#
#    gb_per_month_included
# 0                   15.0
# 1                   30.0

# %%
df_general_agg.head(10)
# Out:
#          month tariff  count_calls  dur_calls  count_messages   mb_used  \
# user_id
# 1000         5  ultra         22.0      159.0            22.0   2253.49
# 1000         6  ultra         43.0      172.0            60.0  23233.77
# 1000         7  ultra         47.0      340.0            75.0  14003.64
# 1000         8  ultra         52.0      408.0            81.0  14055.93
# 1000         9  ultra         58.0      466.0            57.0  14568.91
# 1000        10  ultra         57.0      350.0            73.0  14702.49
# 1000        11  ultra         43.0      338.0            58.0  14756.47
# 1000        12  ultra         46.0      333.0            70.0   9817.61
# 1001        11  smart         59.0      430.0             0.0  18429.34
# 1001        12  smart         63.0      414.0             0.0  14036.66
#
#          gb_used  messages_included  mb_per_month_included  minutes_included  \
# user_id
# 1000         3.0               1000                  30720              3000
# 1000        23.0               1000                  30720              3000
# 1000        14.0               1000                  30720              3000
# 1000        14.0               1000                  30720              3000
# 1000        15.0               1000                  30720              3000
# 1000        15.0               1000                  30720              3000
# 1000        15.0               1000                  30720              3000
# 1000        10.0               1000                  30720              3000
# 1001        18.0                 50                  15360               500
# 1001        14.0                 50                  15360               500
#
#          rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# user_id
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1001                 550         200                3               3
# 1001                 550         200                3               3
#
#         tariff_name  gb_per_month_included       city  revenue
# user_id
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0
# 1001          smart                   15.0     Москва   1150.0
# 1001          smart                   15.0     Москва    550.0

# %% [markdown]
# ### Step 3. Data analysis

# %% [markdown]
# ####  Graphs of average values by months for each of the parameters:

# %%
def barplot_style(x,y,z):
    x.plot(kind='bar', figsize=(12, 5)).set_title(z, fontsize=14)
    plt.xlabel(y, fontsize=12)
    plt.ylabel('Values', fontsize=12)

# %%
df_dur_calls_smart = df_general_agg[df_general_agg['tariff_name'] == 'smart'].pivot_table(index='month', values='dur_calls')

# %%
df_dur_calls_ultra = df_general_agg[df_general_agg['tariff_name'] == 'ultra'].pivot_table(index='month', values='dur_calls')

# %%
barplot_style(df_dur_calls_smart.join(df_dur_calls_ultra, how='outer', lsuffix='_smart', rsuffix='_ultra'),'Month','Call duration statistics for "Smart" and "Ultra"')

# %% [markdown]
# The average duration of calls by months shows a symmetrical growth up to certain values. The `Smart` tariff has increased the average duration of calls to 450 minutes, the `Ultra` tariff has grown to 550 minutes. Despite the fact that the `Ultra` tariff has a duration limit of 3000 minutes, there is no trend towards significant further growth.

# %%
df_count_mess_smart = df_general_agg[df_general_agg['tariff_name'] == 'smart'].pivot_table(index='month', values='count_messages')

# %%
df_count_mess_ultra = df_general_agg[df_general_agg['tariff_name'] == 'ultra'].pivot_table(index='month', values='count_messages')

# %%
barplot_style(df_count_mess_smart.join(df_count_mess_ultra, how='outer', lsuffix='_smart', rsuffix='_ultra'),'Month','SMS message statistics for "Smart" and "Ultra"')

# %% [markdown]
# The `Smart` tariff shows an increase in the number of messages to 40. Clients on average do not use the entire supply of SMS messages. On the `Ultra` tariff, the average number of SMS messages per month is growing steadily and reaches 70. Since the limit on this tariff is 1000 SMS messages, the growth will most likely continue in the future.

# %%
df_count_traff_smart = df_general_agg[df_general_agg['tariff_name'] == 'smart'].pivot_table(index='month', values='gb_used')

# %%
df_count_traff_ultra = df_general_agg[df_general_agg['tariff_name'] == 'ultra'].pivot_table(index='month', values='gb_used')

# %%
barplot_style(df_count_traff_smart.join(df_count_traff_ultra, how='outer', lsuffix='_smart', rsuffix='_ultra'),'Month','Web traffic statistics (GB) for "Smart" and "Ultra"')

# %% [markdown]
# This graph demonstrates the symmetrical growth of web traffic for both tariffs. Despite the fact that the `Ultra` tariff provides 30GB of Internet traffic, few people use it completely. On average, the `Ultra` tariff consumes about 20GB of traffic.

# %%
df_general_agg[df_general_agg['tariff_name'] == 'smart']
# Out:
#          month tariff  count_calls  dur_calls  count_messages   mb_used  \
# user_id
# 1001        11  smart         59.0      430.0             0.0  18429.34
# 1001        12  smart         63.0      414.0             0.0  14036.66
# 1002         6  smart         15.0      117.0             4.0  10856.82
# 1002         7  smart         26.0      214.0            11.0  17580.10
# 1002         8  smart         42.0      289.0            13.0  20319.26
# ...        ...    ...          ...        ...             ...       ...
# 1498        10  smart         41.0      247.0            42.0  20579.36
# 1499         9  smart          9.0       70.0            11.0   1845.75
# 1499        10  smart         68.0      449.0            48.0  17788.51
# 1499        11  smart         74.0      612.0            59.0  17963.31
# 1499        12  smart         69.0      492.0            66.0  13055.58
#
#          gb_used  messages_included  mb_per_month_included  minutes_included  \
# user_id
# 1001        18.0                 50                  15360               500
# 1001        14.0                 50                  15360               500
# 1002        11.0                 50                  15360               500
# 1002        18.0                 50                  15360               500
# 1002        20.0                 50                  15360               500
# ...          ...                ...                    ...               ...
# 1498        21.0                 50                  15360               500
# 1499         2.0                 50                  15360               500
# 1499        18.0                 50                  15360               500
# 1499        18.0                 50                  15360               500
# 1499        13.0                 50                  15360               500
#
#          rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# user_id
# 1001                 550         200                3               3
# 1001                 550         200                3               3
# 1002                 550         200                3               3
# 1002                 550         200                3               3
# 1002                 550         200                3               3
# ...                  ...         ...              ...             ...
# 1498                 550         200                3               3
# 1499                 550         200                3               3
# 1499                 550         200                3               3
# 1499                 550         200                3               3
# 1499                 550         200                3               3
#
#         tariff_name  gb_per_month_included         city  revenue
# user_id
# 1001          smart                   15.0       Москва   1150.0
# 1001          smart                   15.0       Москва    550.0
# 1002          smart                   15.0  Стерлитамак    550.0
# 1002          smart                   15.0  Стерлитамак   1150.0
# 1002          smart                   15.0  Стерлитамак   1550.0
# ...             ...                    ...          ...      ...
# 1498          smart                   15.0  Владикавказ   1750.0
# 1499          smart                   15.0        Пермь    550.0
# 1499          smart                   15.0        Пермь   1150.0
# 1499          smart                   15.0        Пермь   1513.0
# 1499          smart                   15.0        Пермь    598.0
#
# [2229 rows x 18 columns]

# %%
df_proceeds_smart = df_general_agg[df_general_agg['tariff_name'] == 'smart'].pivot_table(
    index='month', values='revenue')

# %%
df_proceeds_ultra = df_general_agg[df_general_agg['tariff_name'] == 'ultra'].pivot_table(index='month', values='revenue')

# %%
barplot_style(df_proceeds_smart.join(df_proceeds_ultra, how='outer', lsuffix='_smart', rsuffix='_ultra'),'Month','Revenue statistics for "Smart" and "Ultra"')

# %% [markdown]
# The graph shows a stable growth of `Smart` tariff revenue, while `Ultra` tariff revenue does not change.

# %% [markdown]
# #### Distribution schedules for each tariff parameter (parameter as a random variable)

# %%
fig = plt.figure(figsize=(12,5))

sns.distplot(a=df_users_calls.loc[df_users_calls['tariff']=='ultra','duration'], 
             bins=50, hist=True, color='red')
sns.distplot(a=df_users_calls.loc[df_users_calls['tariff']=='smart','duration'], 
             bins=50, hist=True, color='blue')

fig.legend(labels=['ultra','smart'])
plt.title('Density distribution \n duration of calls of "Smart" and "Ultra" tariffs', fontsize=14);
plt.xlabel('values', fontsize=12)
plt.ylabel('density distribution', fontsize=12)

plt.show()
# Out:
# C:\Users\Vadim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Vadim\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The plots show a symmetrical normal distribution. The most frequent calls are about 6 minutes long.

# %%
fig = plt.figure(figsize=(12,5))

sns.distplot(a=df_users_internet.loc[df_users_internet['tariff']=='ultra','mb_used'], 
             bins=50, hist=True, color='red')
sns.distplot(a=df_users_internet.loc[df_users_internet['tariff']=='smart','mb_used'], 
             bins=50, hist=True, color='blue')

fig.legend(labels=['ultra','smart'])
plt.title('Distribution of traffic volume densities (Mb)\n by sessions for "Smart" and "Ultra" tariffs', fontsize=14);
plt.xlabel('values', fontsize=12)
plt.ylabel('density distribution', fontsize=12)

plt.show()

# %% [markdown]
# The graph looks like a normal distribution. Tariff `Ultra` shows more traffic consumption. Average around 500MB. For the `Smart` tariff, the average value is about 300MB per session. The `Ultra` tariff is generally characterized by a greater consumption of traffic. This is logical based on the conditions of both tariffs.

# %%
fig = plt.figure(figsize=(12,5))

sns.distplot(df_general_agg.loc[df_general_agg['tariff_name'] == 'ultra', 'count_messages'], 
             bins=50, hist=True, color='red')
sns.distplot(df_general_agg.loc[df_general_agg['tariff_name'] == 'smart', 'count_messages'], 
             bins=50, hist=True, color='blue')

fig.legend(labels=['ultra','smart'])
plt.title('Distribution of the number of SMS messages \n per month for "Smart" and "Ultra" tariffs', fontsize=14);
plt.xlabel('values', fontsize=12)
plt.ylabel('density distribution', fontsize=12)

plt.show()

# %% [markdown]
# The most frequent number of messages sent monthly is in the range of 20-25. A little less than 1 post per day. This situation is typical for both tariffs.

# %%
fig = plt.figure(figsize=(12,5))

sns.distplot(a=df_general_agg.loc[df_general_agg['tariff_name'] == 'ultra', 'revenue'], 
             bins=10, hist=True, color='red')
sns.distplot(a=df_general_agg.loc[df_general_agg['tariff_name'] == 'smart', 'revenue'], 
             bins=10, hist=True, color='blue')

fig.legend(labels=['ultra','smart'])
plt.title('Distribution of revenue \n per month for "Smart" and "Ultra" tariffs', fontsize=14);
plt.xlabel('values', fontsize=12)
plt.ylabel('density distribution', fontsize=12)

plt.show()

# %% [markdown]
# The most frequent values are close to the values of the subscription fee. This is true for both tariffs. Large values tend to zero.

# %% [markdown]
# #### Calculation of the mean, variance and standard deviation for each tariff parameter

# %% [markdown]
# Let's calculate the mathematical expectation, variance and standard deviation for each random variable from the sample. The mathematical expectation is equal to the mean if the outcomes are equally likely. We will assume that the probability of getting different values for such parameters as the duration of calls, the number of messages and the amount of traffic is the same.

# %%
df_general_agg.head(2)
# Out:
#          month tariff  count_calls  dur_calls  count_messages   mb_used  \
# user_id
# 1000         5  ultra         22.0      159.0            22.0   2253.49
# 1000         6  ultra         43.0      172.0            60.0  23233.77
#
#          gb_used  messages_included  mb_per_month_included  minutes_included  \
# user_id
# 1000         3.0               1000                  30720              3000
# 1000        23.0               1000                  30720              3000
#
#          rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# user_id
# 1000                1950         150                1               1
# 1000                1950         150                1               1
#
#         tariff_name  gb_per_month_included       city  revenue
# user_id
# 1000          ultra                   30.0  Краснодар   1950.0
# 1000          ultra                   30.0  Краснодар   1950.0

# %%
np.var(df_general_agg['dur_calls'], ddof=1)
# Out:
# 58520.437687610414

# %%
np.var(df_general_agg['dur_calls'])
# Out:
# 58502.22971073188

# %%
df_general_agg
# Out:
#          month tariff  count_calls  dur_calls  count_messages   mb_used  \
# user_id
# 1000         5  ultra         22.0      159.0            22.0   2253.49
# 1000         6  ultra         43.0      172.0            60.0  23233.77
# 1000         7  ultra         47.0      340.0            75.0  14003.64
# 1000         8  ultra         52.0      408.0            81.0  14055.93
# 1000         9  ultra         58.0      466.0            57.0  14568.91
# ...        ...    ...          ...        ...             ...       ...
# 1498        10  smart         41.0      247.0            42.0  20579.36
# 1499         9  smart          9.0       70.0            11.0   1845.75
# 1499        10  smart         68.0      449.0            48.0  17788.51
# 1499        11  smart         74.0      612.0            59.0  17963.31
# 1499        12  smart         69.0      492.0            66.0  13055.58
#
#          gb_used  messages_included  mb_per_month_included  minutes_included  \
# user_id
# 1000         3.0               1000                  30720              3000
# 1000        23.0               1000                  30720              3000
# 1000        14.0               1000                  30720              3000
# 1000        14.0               1000                  30720              3000
# 1000        15.0               1000                  30720              3000
# ...          ...                ...                    ...               ...
# 1498        21.0                 50                  15360               500
# 1499         2.0                 50                  15360               500
# 1499        18.0                 50                  15360               500
# 1499        18.0                 50                  15360               500
# 1499        13.0                 50                  15360               500
#
#          rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# user_id
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# 1000                1950         150                1               1
# ...                  ...         ...              ...             ...
# 1498                 550         200                3               3
# 1499                 550         200                3               3
# 1499                 550         200                3               3
# 1499                 550         200                3               3
# 1499                 550         200                3               3
#
#         tariff_name  gb_per_month_included         city  revenue
# user_id
# 1000          ultra                   30.0    Краснодар   1950.0
# 1000          ultra                   30.0    Краснодар   1950.0
# 1000          ultra                   30.0    Краснодар   1950.0
# 1000          ultra                   30.0    Краснодар   1950.0
# 1000          ultra                   30.0    Краснодар   1950.0
# ...             ...                    ...          ...      ...
# 1498          smart                   15.0  Владикавказ   1750.0
# 1499          smart                   15.0        Пермь    550.0
# 1499          smart                   15.0        Пермь   1150.0
# 1499          smart                   15.0        Пермь   1513.0
# 1499          smart                   15.0        Пермь    598.0
#
# [3214 rows x 18 columns]

# %%
np.var(df_general_agg.loc[df_general_agg['tariff_name'] == 'ultra']['dur_calls'])
# Out:
# 100771.22361720214

# %%
np.var(df_general_agg.loc[df_general_agg['tariff_name'] == 'ultra']['dur_calls'], ddof=1)
# Out:
# 100873.63339730092

# %% [markdown]
# **Calculation of the mean, variance and standard deviation for the Ultra tariff:**

# %%
df_general_agg.loc[df_general_agg['tariff_name'] == 'ultra'].agg({'dur_calls' : ['mean', 'var', 'std'], 
                    'count_messages': ['mean', 'var', 'std'], 
                    'gb_used': ['mean', 'var', 'std'], 
                    'revenue': ['mean', 'var', 'std']}).round()
# Out:
#       dur_calls  count_messages  gb_used   revenue
# mean      527.0            49.0     19.0    2070.0
# var    100874.0          2285.0     97.0  141517.0
# std       318.0            48.0     10.0     376.0

# %% [markdown]
# **Calculation of mean, variance and standard deviation for the Smart tariff:**

# %%
df_general_agg.loc[df_general_agg['tariff_name'] == 'smart'].agg({'dur_calls' : ['mean', 'var', 'std'], 
                    'count_messages': ['mean', 'var', 'std'], 
                    'gb_used': ['mean', 'var', 'std'], 
                    'revenue': ['mean', 'var', 'std']}).round()
# Out:
#       dur_calls  count_messages  gb_used   revenue
# mean      418.0            33.0     16.0    1290.0
# var     36219.0           797.0     33.0  669786.0
# std       190.0            28.0      6.0     818.0

# %% [markdown]
# ### Step 4. Hypothesis testing

# %% [markdown]
# #### Testing the 1st hypothesis: the average revenue of users of the Ultra and Smart tariffs are different

# %% [markdown]
# H0 — the average revenue of Ultra tariff users is equal to the average revenue of Smart tariff users.
#
# H1 - the average revenue of users of the "Ultra" and "Smart" tariffs are different.
#
# α=1%

# %%
alpha = .01

results = st.ttest_ind(df_general_agg.loc[df_general_agg['tariff_name'] == 'ultra', 'revenue'],
                       df_general_agg.loc[df_general_agg['tariff_name'] == 'smart', 'revenue'],
                       equal_var=False,
                       nan_policy='omit')

# %%
results.pvalue
# Out:
# 4.2606313931076085e-250

# %%
if results.pvalue < alpha:
    print("Rejecting the null hypothesis")
else:
    print("Failed to reject the null hypothesis")
# Out:
# Failed to reject the null hypothesis

# %%
df_general_agg.pivot_table(index='tariff_name', values='revenue', aggfunc='median')
# Out:
#              revenue
# tariff_name
# smart         1023.0
# ultra         1950.0

# %%
_ = sns.catplot(x="tariff_name", y='revenue', kind="violin", data=df_general_agg, orient='v')

# %%
_ = sns.catplot(x="tariff_name", y='revenue', kind="box", data=df_general_agg, orient='v')

# %% [markdown]
# Almost all Ultra tariff revenue values are equal to 1950, while 25% of Smart tariff revenue values are almost twice as much. The median revenue value of the Smart tariff is two times less (1000 versus 1950).
# This suggests that the user of the Smart tariff does not have enough tariff package, as a result, he pays extra for additional services. The user of the Ultra tariff, on the contrary, almost always fits into the tariff plan and does not overpay for using services in excess of the tariff plan.

# %% [markdown]
# #### Testing the 2nd hypothesis: the average revenue of users from Moscow differs from the revenue of users from other regions.

# %% [markdown]
# H0 — the average revenue of users from Moscow is equal to the average revenue of users from other regions.
#
# H1 — the average revenue of users from Moscow differs from the average revenue of users from other regions.
#
# α=1%

# %%
alpha = .01

results = st.ttest_ind(df_general_agg.loc[df_general_agg['city'] == 'Москва', 'revenue'],
                       df_general_agg.loc[df_general_agg['tariff_name'] != 'Москва', 'revenue'],
                       equal_var=False,
                       nan_policy='omit')

# %%
results.pvalue
# Out:
# 0.5989670526299272

# %%
if results.pvalue < alpha:
    print("Rejecting the null hypothesis")
else:
    print("Failed to reject the null hypothesis")
# Out:
# Failed to reject the null hypothesis

# %%
def det_region(city):
    if city == 'Москва': return 'Москва'
    else: return 'Other city'
    
df_general_agg['cat_city'] = df_general_agg['city'].apply(det_region)

# %%
df_general_agg.pivot_table(index='cat_city', values='revenue', aggfunc='median')
# Out:
#             revenue
# cat_city
# Other city   1583.0
# Москва       1750.0

# %%
_ = sns.catplot(x='cat_city', y='revenue', kind="violin", data=df_general_agg, orient='v')

# %%
_ = sns.catplot(x='cat_city', y='revenue', kind="box", data=df_general_agg, orient='v')

# %% [markdown]
# The average revenue from users from Moscow is almost the same as from users from other regions. The null hypothesis is confirmed.

# %% [markdown]
# ### Step 5. Conclusions

# %% [markdown]
# In accordance with the statistical analysis of this sample, the revenue for the Ultra tariff is greater than for Smart. On average, the revenue from one user of the Ultra tariff per month is 1950 rubles, from one user of the Smart tariff - 1023 rubles. It turns out the tariff "Ultra" is more profitable for the company "Megaline".
#
# - Smart tariff users lack services within the tariff package: in addition to the subscription fee, users on average pay another 473 rubles monthly (+86%).
# - Users of the "Ultra" tariff, on the contrary, do not use the tariff package in full.
# - Average revenues from users in Moscow do not differ from revenues in other cities: the difference is statistically insignificant (p-value: 0.59) and amounts to 167 rubles: 1750 rubles. in Moscow against 1583 rubles in other cities.
